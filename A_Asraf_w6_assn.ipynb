# %%
import pandas as pd
import matplotlib.pyplot as plt
data_frame = pd.read_csv('/Users/AdvaAsraf/Desktop/Analytics Programming/diamonds.csv')

# %% [markdown]
# ### 1: What proportion of diamonds are between .30 and 1.08 carats?
# ***
#
# For this question I set 2 conditions in order to find the needed carat range within the file. Later on, I pulled up the rows that match my conditions

# %%
condition1 = data_frame['carat'] > 0.30
condition2 = data_frame['carat'] < 1.08
final_condition = condition1 & condition2
column_name = ['carat']

data_frame.loc[final_condition, column_name]
# Out:
#        carat
# 4       0.31
# 13      0.31
# 15      0.32
# 23      0.31
# 24      0.31
# 37      0.31
# 39      0.33
# 40      0.33
# 41      0.33
# 44      0.32
# 46      0.32
# 47      0.32
# 52      0.32
# 60      0.35
# 64      0.42
# 66      0.32
# 67      0.31
# 68      0.31
# 83      0.38
# 89      0.32
# 90      0.70
# 91      0.86
# 92      0.70
# 93      0.71
# 94      0.78
# 95      0.70
# 96      0.70
# 97      0.96
# 98      0.73
# 99      0.80
# ...      ...
# 53910   0.70
# 53911   0.57
# 53912   0.61
# 53913   0.80
# 53914   0.84
# 53915   0.77
# 53916   0.74
# 53917   0.90
# 53918   0.76
# 53919   0.76
# 53920   0.70
# 53921   0.70
# 53922   0.70
# 53923   0.73
# 53924   0.73
# 53925   0.79
# 53926   0.71
# 53927   0.79
# 53928   0.79
# 53929   0.71
# 53930   0.71
# 53931   0.71
# 53932   0.70
# 53933   0.70
# 53934   0.72
# 53935   0.72
# 53936   0.72
# 53937   0.70
# 53938   0.86
# 53939   0.75
#
# [37434 rows x 1 columns]

# %% [markdown]
# ### 2: How many of the diamonds have equal x and y dimensions?
#
# ***
#
# Answer: None of the values of x and y are exactly equal. So it will return False.

# %%
data_frame['x'].equals(data_frame['y'])
# Out:
# False

# %% [markdown]
# ### 3: How many of the diamonds have a carat less than the mean carat value?
#
# ***
#
# For this question, first I found the mean carat value by using Panda's desribe funcstion. Once I did, I pulled up all the rows that have a carat value that is lower than the mean

# %%
data_frame['carat'].describe()
# Out:
# count    53940.000000
# mean         0.797940
# std          0.474011
# min          0.200000
# 25%          0.400000
# 50%          0.700000
# 75%          1.040000
# max          5.010000
# Name: carat, dtype: float64

# %%
condition = data_frame['carat'] < 0.797940
data_frame[condition]
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5       0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6       0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7       0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8       0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9       0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39
# 10      0.30       Good     J     SI1   64.0   55.0    339  4.25  4.28  2.73
# ...

# %% [markdown]
# ### 4: How many diamonds have a Premium cut or better? Note that the possible values for the quality of a cut are ranked in ascending order as follows: Fair / Good / Very Good / Premium / Ideal
#
# ***
#
# There is only one cut that is better than premiun according to the CSV file; IDEAL, therefore I set 2 conditons. The first one was to find all rows with a cut of permium. The second one was to find all rows with ideal cut. Then, I pulled up the data by presenting both conditions.

# %%
condition = data_frame['cut'] == 'Premium'
condition2 = data_frame['cut'] == 'Ideal'
result = condition | condition2
data_frame[result]
# Out:
#        carat      cut color clarity  depth  table  price     x     y     z
# 0       0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3       0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 11      0.23    Ideal     J     VS1   62.8   56.0    340  3.93  3.90  2.46
# 12      0.22  Premium     F     SI1   60.4   61.0    342  3.88  3.84  2.33
# 13      0.31    Ideal     J     SI2   62.2   54.0    344  4.35  4.37  2.71
# 14      0.20  Premium     E     SI2   60.2   62.0    345  3.79  3.75  2.27
# 15      0.32  Premium     E      I1   60.9   58.0    345  4.38  4.42  2.68
# 16      0.30    Ideal     I     SI2   62.0   54.0    348  4.31  4.34  2.68
# 26      0.24  Premium     I     VS1   62.5   57.0    355  3.97  3.94  2.47
# 39      0.33    Ideal     I     SI2   61.8   55.0    403  4.49  4.51  2.78
# ...

# %% [markdown]
# ### 5: Which diamond has the highest price per carat? What is its value?
#
# ***
#
# In order to find the highest price per carat I used Panda's describe for the price column. The Max value is the highest price per carat diamond.

# %%
data_frame['price'].describe()
# Out:
# count    53940.000000
# mean      3932.799722
# std       3989.439738
# min        326.000000
# 25%        950.000000
# 50%       2401.000000
# 75%       5324.250000
# max      18823.000000
# Name: price, dtype: float64

# %% [markdown]
# Answer: The maximum value is: max   18823.000000

# %% [markdown]
# ###   6: Make a bar plot of the ‘cut’ data. What does it tell us about the frequencies of the individual cut values within the data set?
#
# ***
#
# I used numpy in order to create the bar chart. I set my columns to the different cut types, and frequencies represent how many of that specific cut was represented in the CSV file
# According to the below bar chart, one can see that most diamons are ideal, followed by premium. The least common cut of diamond was "fair". One can assume that when a buyer buys a diamond, he preferes to spend his money wisely and to buy a good quality diamond.

# %%
import numpy as np
frequency = data_frame['cut'].value_counts()
objects = ['Ideal', 'Premium', 'Very Good', 'Good', 'Fair']
y_pos = np.arange(len(objects))
new=[]
for i in range(5):
    new.append(frequency[i])

plt.bar(y_pos, new, align='center', alpha=0.5)
plt.xticks(y_pos,objects)
plt.xlabel('Cut')
plt.ylabel('Frequencies of cut values') 
plt.show()

# %% [markdown]
# ###  7: Make boxplots of the diamond price for each cut and discuss any conclusions you can draw from the appearance of the boxplots.
#
# ***
#
# Looking at the different box plots below, one can easily notice that the median in each diamond cut box plot is very similar. Same goes for the minimum, first quartile, third quartile and the max

# %%
data_frame.boxplot(by ='cut', column =['price'],grid = False)
plt.show()

# %% [markdown]
# ###   8: Make histograms of the length, width, depth, and total depth attributes and discuss any conclusions you can draw from the shape of the resulting distributions.

# %%
data_frame[['x']].plot(kind='hist',rwidth=0.8)
plt.show()
data_frame[['y']].plot(kind='hist',rwidth=0.8)
plt.show()
data_frame[['z']].plot(kind='hist',rwidth=0.8)
plt.show()
data_frame[['depth']].plot(kind='hist',rwidth=0.8)
plt.show()

# %% [markdown]
# ###  9: Make a scatter plot of price vs. carat. What can we say about the relationship between those two attributes?
#
# ***
#
# This scatter plot shows that most of the data points are between 0-2.5 carats. Price is also increasing with the increase in carats. But not for all of them. Some of the data points of around 3 carats are at low price too.

# %%
data_frame.plot(kind='scatter',x='carat',y='price')
plt.show()
